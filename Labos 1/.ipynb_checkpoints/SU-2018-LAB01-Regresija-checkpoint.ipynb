# %% [markdown]
# Sveučilište u Zagrebu
# Fakultet elektrotehnike i računarstva
#
# ## Strojno učenje 2018/2019
# http://www.fer.unizg.hr/predmet/su

# %% [markdown]
# ------------------------------
#
# ### Laboratorijska vježba 1: Regresija
#
# *Verzija: 1.1
# Zadnji put ažurirano: 12. listopada 2018.*
#
# (c) 2015-2018 Jan Šnajder, Domagoj Alagić, Mladen Karan
#
# Objavljeno: **12. listopada 2018.**
# Rok za predaju: **22. listopada 2018. u 07:00h**
#
# ------------------------------

# %% [markdown]
# ### Upute
#
# Prva laboratorijska vježba sastoji se od osam zadataka. U nastavku slijedite upute navedene u ćelijama s tekstom. Rješavanje vježbe svodi se na **dopunjavanje ove bilježnice**: umetanja ćelije ili više njih **ispod** teksta zadatka, pisanja odgovarajućeg kôda te evaluiranja ćelija.
#
# Osigurajte da u potpunosti **razumijete** kôd koji ste napisali. Kod predaje vježbe, morate biti u stanju na zahtjev asistenta (ili demonstratora) preinačiti i ponovno evaluirati Vaš kôd. Nadalje, morate razumjeti teorijske osnove onoga što radite, u okvirima onoga što smo obradili na predavanju. Ispod nekih zadataka možete naći i pitanja koja služe kao smjernice za bolje razumijevanje gradiva (**nemojte pisati** odgovore na pitanja u bilježnicu). Stoga se nemojte ograničiti samo na to da riješite zadatak, nego slobodno eksperimentirajte. To upravo i jest svrha ovih vježbi.
#
# Vježbe trebate raditi **samostalno**. Možete se konzultirati s drugima o načelnom načinu rješavanja, ali u konačnici morate sami odraditi vježbu. U protivnome vježba nema smisla.

# %%
# Učitaj osnovne biblioteke...
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Zadatci

# %% [markdown]
# ### 1. Jednostavna regresija

# %% [markdown]
# Zadan je skup primjera $\mathcal{D}=\{(x^{(i)},y^{(i)})\}_{i=1}^4 = \{(0,4),(1,1),(2,2),(4,5)\}$. Primjere predstavite matrixom $\mathbf{X}$ dimenzija $N\times n$ (u ovom slučaju $4\times 1$) i vektorom oznaka $\textbf{y}$, dimenzija $N\times 1$ (u ovom slučaju $4\times 1$), na sljedeći način:

# %%
X = np.array([[0],[1],[2],[4]])
y = np.array([4,1,2,5])

# %% [markdown]
# #### (a)
#
# Proučite funkciju [`PolynomialFeatures`](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html) iz biblioteke `sklearn` i upotrijebite je za generiranje matrice dizajna $\mathbf{\Phi}$ koja ne koristi preslikavanje u prostor više dimenzije (samo će svakom primjeru biti dodane *dummy* jedinice; $m=n+1$).

# %%
#generira matricu značajki koja se sastoji od svih kombinacija danih značajki do specificiranog stupnja = matrica dizajna

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(1)
psi=poly.fit_transform(X)

# %% [markdown]
# #### (b)

# %% [markdown]
# Upoznajte se s modulom [`linalg`](http://docs.scipy.org/doc/numpy/reference/routines.linalg.html). Izračunajte težine $\mathbf{w}$ modela linearne regresije kao $\mathbf{w}=(\mathbf{\Phi}^\intercal\mathbf{\Phi})^{-1}\mathbf{\Phi}^\intercal\mathbf{y}$. Zatim se uvjerite da isti rezultat možete dobiti izračunom pseudoinverza $\mathbf{\Phi}^+$ matrice dizajna, tj. $\mathbf{w}=\mathbf{\Phi}^+\mathbf{y}$, korištenjem funkcije [`pinv`](http://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.pinv.html).

# %%
from numpy import linalg

# %%
#prvi nacin
temp = np.matmul(psi.transpose(), psi)
temp = linalg.inv(temp)
temp = np.matmul(temp, psi.transpose())
w1 = np.matmul(temp,y )

#drugi nacin
#pinv direktno izracunava pseudoinverz
w2=np.matmul(linalg.pinv(psi), y)

print(w1,w2)
# Out:
# [2.2        0.45714286] [2.2        0.45714286]

# %% [markdown]
# Radi jasnoće, u nastavku je vektor $\mathbf{x}$ s dodanom *dummy* jedinicom $x_0=1$ označen kao $\tilde{\mathbf{x}}$.

# %% [markdown]
# #### (c)

# %% [markdown]
# Prikažite primjere iz $\mathcal{D}$ i funkciju $h(\tilde{\mathbf{x}})=\mathbf{w}^\intercal\tilde{\mathbf{x}}$. Izračunajte pogrešku učenja prema izrazu $E(h|\mathcal{D})=\frac{1}{2}\sum_{i=1}^N(\tilde{\mathbf{y}}^{(i)} - h(\tilde{\mathbf{x}}))^2$. Možete koristiti funkciju srednje kvadratne pogreške [`mean_squared_error`]( http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error) iz modula [`sklearn.metrics`](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics).
#
# **Q:** Gore definirana funkcija pogreške $E(h|\mathcal{D})$ i funkcija srednje kvadratne pogreške nisu posve identične. U čemu je razlika? Koja je "realnija"?

# %%
x_tilda = psi #nadodan dummy
w = np.reshape(w1,(-1,1)) #vektor u matricu sa jednom dimenzijom 1 kako bi se izvelo mnozenje s matricom
h = np.matmul(x_tilda, w)  #krivo gori pise  x je oblika (4,2) a w je (2,1)

h = h.flatten()
E = 0.5*np.sum((y-h)**2)
print(E)

#Fali normalizacija s brojem primjera, tj u nazivniku fali N. Ova nije relana jer s vecim brojem primjera 
#vise raste greska, a kad se noralizira promotramo prosjecnu gresku sto je relanije
# Out:
# 4.085714285714286

# %% [markdown]
# #### (d)

# %% [markdown]
# Uvjerite se da za primjere iz $\mathcal{D}$ težine $\mathbf{w}$ ne možemo naći rješavanjem sustava $\mathbf{w}=\mathbf{\Phi}^{-1}\mathbf{y}$, već da nam doista treba pseudoinverz.
#
# **Q:** Zašto je to slučaj? Bi li se problem mogao riješiti preslikavanjem primjera u višu dimenziju? Ako da, bi li to uvijek funkcioniralo, neovisno o skupu primjera $\mathcal{D}$? Pokažite na primjeru.

# %%
linalg.inv(psi) #javi error jer inverz zahtjeva square matrix, a pseudoinverz ne
#pseudoinverz se definira tako da rjsi sustav jednazbi koji nama triba
#inverz se defnira kao matirca za koji vrjedi A*A^-1=1 i radi toga mora bit kvadratana
#nisna ovo sig al mislmi da bi se moglo rjesit preslikavnajemm u visu dimezniju, al dimenzija bi morala bit koliko imas podataka i onda bi dobila 
#preogormnu matricu  kojoj bi se sporo racuna inverz, triba lao pogledat u skripti
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-61-999c01efabdd> in <module>()
# ----> 1 linalg.inv(psi)
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     525     a, wrap = _makearray(a)
#     526     _assertRankAtLeast2(a)
# --> 527     _assertNdSquareness(a)
#     528     t, result_t = _commonType(a)
#     529
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _assertNdSquareness(*arrays)
#     213         m, n = a.shape[-2:]
#     214         if m != n:
# --> 215             raise LinAlgError('Last 2 dimensions of the array must be square')
#     216
#     217 def _assertFinite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %% [markdown]
# #### (e)

# %% [markdown]
# Proučite klasu [`LinearRegression`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression) iz modula [`sklearn.linear_model`](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model). Uvjerite se da su težine koje izračunava ta funkcija (dostupne pomoću atributa `coef_` i `intercept_`) jednake onima koje ste izračunali gore. Izračunajte predikcije modela (metoda `predict`) i uvjerite se da je pogreška učenja identična onoj koju ste ranije izračunali.

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X, y)
print("Score iznosi: ", reg.score(X, y))
print("Trenutno izracunato: ")
print(reg.intercept_ )
print(reg.coef_)
print("Ranije izracunato: ")
print(w)

prediction = reg.predict(X)
print("Predikcija: ", prediction)
# Out:
# Score iznosi:  0.18285714285714272
# Trenutno izracunato:
# 2.2
# [0.45714286]
# Ranije izracunato:
# [[2.2       ]
#  [0.45714286]]
# Predikcija:  [2.2        2.65714286 3.11428571 4.02857143]

# %% [markdown]
# ### 2. Polinomijalna regresija i utjecaj šuma

# %% [markdown]
# #### (a)
#
# Razmotrimo sada regresiju na većem broju primjera. Koristite funkciju `make_labels(X, f, noise=0)` koja uzima matricu neoznačenih primjera $\mathbf{X}_{N\times n}$ te generira vektor njihovih oznaka $\mathbf{y}_{N\times 1}$. Oznake se generiraju kao $y^{(i)} = f(x^{(i)})+\mathcal{N}(0,\sigma^2)$, gdje je $f:\mathbb{R}^n\to\mathbb{R}$ stvarna funkcija koja je generirala podatke (koja nam je u stvarnosti nepoznata), a $\sigma$ je standardna devijacija Gaussovog šuma, definirana parametrom `noise`. Za generiranje šuma koristi se funkcija [`numpy.random.normal`](http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.normal.html).
#
# Generirajte skup za učenje od $N=50$ primjera uniformno distribuiranih u intervalu $[-5,5]$ pomoću funkcije $f(x) = 5 + x -2 x^2 -5 x^3$ uz šum  $\sigma=200$:

# %%
from numpy.random import normal
def make_labels(X, f, noise=0) :
    return map(lambda x : f(x) + (normal(0,noise) if noise>0 else 0), X)

# %%
def make_instances(x1, x2, N) :
    return np.array([np.array([x]) for x in np.linspace(x1, x2, N)])
#def make_instances(x1, x2, N):
#    instances = np.array([])
#    for x in np.linspace(x1, x2, N):
#        instances.append(x)
#    return instances

# %%
def f(x):
    return 5+x-2*x**2-5*x**3
X = make_instances(-5, 5, 50)
#y= make_labels(X, f, 200)
#print(y)
y = list(make_labels(X, f, 200))  #ovaj map se ponaas kao neki generator ne vrati sve odjednom nego kako je pozivbas vraca iduci elemnt, pa ga se ocvako natira da vrati sve
y = np.array(y)
print(y)
# Out:
# [[ 409.5010408 ]
#  [ 318.75064624]
#  [ 394.99353996]
#  [ 673.51615412]
#  [ 425.60513436]
#  [ 294.19247968]
#  [ 325.247145  ]
#  [ 136.94721955]
#  [  43.41163763]
#  [ 353.92338357]
#  [ 391.44315218]
#  [-103.56218714]
#  [-212.92564619]
#  [-126.30593902]
#  [ -19.09097976]
#  [ -23.69247562]
#  [  66.48378619]
#  [ -23.02930781]
#  [ 286.64149056]
#  [-125.90065084]
#  [ -19.73592853]
#  [ -10.60802259]
#  [ 293.20161734]
#  [ 148.72196   ]
#  [ 275.24959902]
#  [ -77.49007967]
#  [ 190.29532505]
#  [  21.40552626]
#  [  18.19748821]
#  [ -95.84676329]
#  [-320.95556332]
#  [ 106.98001555]
#  [-111.81861574]
#  [-142.42147762]
#  [ -58.7700535 ]
#  [-645.84040555]
#  [ -79.20382719]
#  [-288.22677505]
#  [ 121.77719242]
#  [  26.52595125]
#  [-105.59286549]
#  [-169.44366487]
#  [-375.8376923 ]
#  [-115.31766365]
#  [-261.16740311]
#  [-208.66114817]
#  [-574.41132282]
#  [-540.79918438]
#  [-658.48310568]
#  [-584.91234944]]

# %% [markdown]
# Prikažite taj skup funkcijom [`scatter`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter).

# %%
plt.scatter(X,y)

# %% [markdown]
# #### (b)

# %% [markdown]
# Trenirajte model polinomijalne regresije stupnja $d=3$. Na istom grafikonu prikažite naučeni model $h(\mathbf{x})=\mathbf{w}^\intercal\tilde{\mathbf{x}}$ i primjere za učenje. Izračunajte pogrešku učenja modela.

# %%
def model(X, y, d):
    poly = PolynomialFeatures(d)
    X_tilda = poly.fit_transform(X)
    weights = np.matmul(linalg.pinv(X_tilda),y)
    return weights, X_tilda

def prediction_and_error(X_tilda, w, y):
    w = np.reshape(w,(-1,1)) #vektor u matricu sa jednom dimenzijom 1
    h = np.matmul(X_tilda,w)
    h = h.flatten()
    E = sklearn.metrics.mean_squared_error(y, h)
    return h,E
        
w, X_tilda = model(X, y, 3)
h, E = prediction_and_error(X_tilda, w, y)

plt.scatter(X, y)
plt.plot(X, h)
plt.show()
print("Greska je ", E)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-1fe03d801798> in <module>()
#      12     return h,E
#      13
# ---> 14 w, X_tilda = model(X, y, 3)
#      15 h, E = prediction_and_error(X_tilda, w, y)
#      16
#
# <ipython-input-110-1fe03d801798> in model(X, y, d)
#       2     poly = PolynomialFeatures(d)
#       3     X_tilda = poly.fit_transform(X)
# ----> 4     weights = np.matmul(linalg.pinv(X_tilda),y)
#       5     return weights, X_tilda
#       6
#
# ValueError: shapes (4,1000) and (500,1) not aligned: 1000 (dim 1) != 500 (dim 0)

# %% [markdown]
# ### 3. Odabir modela

# %% [markdown]
# #### (a)
#
# Na skupu podataka iz zadatka 2 trenirajte pet modela linearne regresije $\mathcal{H}_d$ različite složenosti, gdje je $d$ stupanj polinoma, $d\in\{1,3,5,10,20\}$. Prikažite na istome grafikonu skup za učenje i funkcije $h_d(\mathbf{x})$ za svih pet modela (preporučujemo koristiti `plot` unutar `for` petlje). Izračunajte pogrešku učenja svakog od modela.
#
# **Q:** Koji model ima najmanju pogrešku učenja i zašto?

# %%
plt.scatter(X, y, label = "data")

for d in [1, 3, 5, 10, 20]:
    w, X_tilda = model(X, y, d)
    h, E = predict_and_error(X_tilda, w, y)
    plt.plot(X, h, label="d = " + str(d))
    print("Greska stupnja ", d, " je: ", E)
plt.legend()
plt.show()


#d=10 i d=20 imaju red velicenine manju gresku radi toga sta overfitaju (zbog velike potencije koju imaju mogu puno puta 
#"skrenut" goer dolje)
# Out:
# Greska stupnja  1  je  43395.86904329544
# Greska stupnja  3  je  38006.859834197654
# Greska stupnja  5  je  37286.565084797636
# Greska stupnja  10  je  36565.32727906462
# Greska stupnja  20  je  30192.385459593635

# %% [markdown]
# #### (b)

# %% [raw]
# # Razdvojite skup primjera iz zadatka 2 pomoću funkcije [`cross_validation.train_test_split`](http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.train_test_split.html#sklearn.cross_validation.train_test_split) na skup za učenja i skup za ispitivanje u omjeru 1:1. Prikažite na jednom grafikonu pogrešku učenja i ispitnu pogrešku za modele polinomijalne regresije $\mathcal{H}_d$, sa stupnjem polinoma $d$ u rasponu $d\in [1,2,\ldots,20]$. Radi preciznosti, funkcije $h(\mathbf{x})$ iscrtajte na cijelom skupu primjera (ali pogrešku generalizacije računajte, naravno, samo na ispitnome skupu). Budući da kvadratna pogreška brzo raste za veće stupnjeve polinoma, umjesto da iscrtate izravno iznose pogrešaka, iscrtajte njihove logaritme.
#
# **NB:** Podjela na skupa za učenje i skup za ispitivanje mora za svih pet modela biti identična.
#
# **Q:** Je li rezultat u skladu s očekivanjima? Koji biste model odabrali i zašto?
#
# **Q:** Pokrenite iscrtavanje više puta. U čemu je problem? Bi li problem bio jednako izražen kad bismo imali više primjera? Zašto?

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

Train_err = []
Test_err = []
for d in range(1, 21):
    w, X_tilda = model(X_train, y_train, d)
    h1, E_train = predict_and_error(X_tilda, w, y_train)
    Train_err.append(np.log(E_train))
    
    poly = PolynomialFeatures(d)
    X_temp = poly.fit_transform(X_test)
    h2, E_test = predict_and_error(X_temp, w, y_test)    
    Test_err.append(np.log(E_test))

plt.plot(d_list, Train_err, label="Log train error")
plt.plot(d_list, Test_err, label="Log test error")
plt.legend()
plt.show()
    
#Rezultat je u skladu s ocekivanjima, povecanjem kompleksnti modela vise doalzi do overfitanja, te dolazi do loše 
#generalizacije koju nam je cilj modelirat. Izabrala bi
#jednostvaniji model do 5. tog stupnja najvise a vjvj i nizi stupanj
#prilikom pokretanja koda vise puta znatno se mjenja oblik grada, to je radi toga što je malo točaka
#pa neki sample bolje opisuje test set a neki lošije, povečanjem broja točaka taj bi efekt skoro pa nestao

# %% [markdown]
# #### (c)

# %% [markdown]
# Točnost modela ovisi o (1) njegovoj složenosti (stupanj $d$ polinoma), (2) broju primjera $N$, i (3) količini šuma. Kako biste to analizirali, nacrtajte grafikone pogrešaka kao u 3b, ali za sve kombinacija broja primjera $N\in\{100,200,1000\}$ i količine šuma $\sigma\in\{100,200,500\}$ (ukupno 9 grafikona). Upotrijebite funkciju [`subplots`](http://matplotlib.org/examples/pylab_examples/subplots_demo.html) kako biste pregledno posložili grafikone u tablicu $3\times 3$. Podatci se generiraju na isti način kao u zadatku 2.
#
# **NB:** Pobrinite se da svi grafikoni budu generirani nad usporedivim skupovima podataka, na sljedeći način. Generirajte najprije svih 1000 primjera, podijelite ih na skupove za učenje i skupove za ispitivanje (dva skupa od po 500 primjera). Zatim i od skupa za učenje i od skupa za ispitivanje načinite tri različite verzije, svaka s drugačijom količinom šuma (ukupno 2x3=6 verzija podataka). Kako bi simulirali veličinu skupa podataka, od tih dobivenih 6 skupova podataka uzorkujte trećinu, dvije trećine i sve podatke. Time ste dobili 18 skupova podataka -- skup za učenje i za testiranje za svaki od devet grafova.

# %% [markdown]
# ***Q:*** Jesu li rezultati očekivani? Obrazložite.

# %%
def fit_and_get_errors(X_train, X_test, y_train, y_test):
    
    Train_err=[]
    Test_err=[]
    for d in range(1, 21):
        w, X_tilda = model(X_train, y_train, d)
        h1, E_train = predict_and_error(X_tilda, w, y_train)
        Train_err.append(np.log(E_train))

        poly = PolynomialFeatures(d)
        X_temp = poly.fit_transform(X_test)
        h2, E_test = predict_and_error(X_temp, w, y_test)    
        Test_err.append(np.log(E_test))
    
    d_list = [i for i in range(1, 21)]
    return d_list, Train_err, Test_err

sigma = [100, 200, 500]
N = [50, 100, 500] #ovliko cemo uzmiat iz test/train skupa

fig, axs = plt.subplots(3, 4, figsize=(15, 15))
axs = axs.ravel()

X = make_instances(-5,5,1000)
X_train, X_test = train_test_split(X, test_size=0.5)

for i, std in enumerate(sigma):
    
    y = list(make_labels(X_train, f, std)) 
    y_train = np.array(y)
    
    y = list(make_labels(X_test,f,std)) 
    y_test = np.array(y)
    
    axs[i*4+3].scatter(X_train, y_train)
    axs[i*4+3].scatter(X_test, y_test)
    axs[i*4+3].set_title("Data for sigma= " + str(std))
    
    for j, n in enumerate(N):
        
        index_list = np.random.choice(np.arange(500), n, replace=False)
        X1_train = X_train[index_list]
        y1_train = y_train[index_list]
        
        index_list = np.random.choice(np.arange(500), n, replace=False)
        X1_test = X_test[index_list]
        y1_test = y_test[index_list]
        
        d,train,test=fit_and_get_errors(X1_train,X1_test,y1_train,y1_test)
        
        axs[i*4+j].set_title("N = " + str(n) + ", sigma = " + str(std))
        axs[i*4+j].plot(d,train,label="Train")
        axs[i*4+j].plot(d,test,label="Test")
        axs[i*4+j].legend()


plt.show()



#Rezultati su ocekivani, kada imamo veliki šum(500)

# %% [markdown]
# ### 4. Regularizirana regresija

# %% [markdown]
# #### (a)
#
# U gornjim eksperimentima nismo koristili **regularizaciju**. Vratimo se najprije na primjer iz zadatka 1. Na primjerima iz tog zadatka izračunajte težine $\mathbf{w}$ za polinomijalni regresijski model stupnja $d=3$ uz L2-regularizaciju (tzv. *ridge regression*), prema izrazu $\mathbf{w}=(\mathbf{\Phi}^\intercal\mathbf{\Phi}+\lambda\mathbf{I})^{-1}\mathbf{\Phi}^\intercal\mathbf{y}$. Napravite izračun težina za regularizacijske faktore $\lambda=0$, $\lambda=1$ i $\lambda=10$ te usporedite dobivene težine.
#
# **Q:** Kojih je dimenzija matrica koju treba invertirati?
#
# **Q:** Po čemu se razlikuju dobivene težine i je li ta razlika očekivana? Obrazložite.

# %%
lambda_niz = [0, 1, 10]
for l in lambda_niz:
    
    X = np.array([[0],[1],[2],[4]])
    y = np.array([4,1,2,5])
    
    poly=PolynomialFeatures(3)
    psi=poly.fit_transform(X)
    
    temp = np.matmul(psi.transpose(), psi)
    temp = temp + l*np.identity(np.shape(temp)[0])
    temp = linalg.inv(temp)
    temp = np.matmul(temp, psi.transpose())
    w = np.matmul(temp, y)
    
    print(w)
# Out:
# [ 4.         -5.91666667  3.375      -0.45833333]
# [ 1.79567372 -0.24729075 -0.0175289   0.07014758]
# [0.43312265 0.11060671 0.13827839 0.03093411]

# %% [markdown]
# #### (b)

# %% [markdown]
# Proučite klasu [`Ridge`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge) iz modula [`sklearn.linear_model`](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model), koja implementira L2-regularizirani regresijski model. Parametar $\alpha$ odgovara parametru $\lambda$. Primijenite model na istim primjerima kao u prethodnom zadatku i ispišite težine $\mathbf{w}$ (atributi `coef_` i `intercept_`).
#
# **Q:** Jesu li težine identične onima iz zadatka 4a? Ako nisu, objasnite zašto je to tako i kako biste to popravili.

# %%
from sklearn.linear_model import Ridge

# %%
lambda_niz = [0, 1, 10]
for l in lambda_niz:
    
    X = np.array([[0],[1],[2],[4]])
    y = np.array([4,1,2,5])
    
    poly = PolynomialFeatures(3)
    psi = poly.fit_transform(X)
    
    clf = Ridge(alpha = l)
    clf.fit(psi, y) 
    print(clf.coef_)
    print(clf.intercept_)
# Out:
# [ 0.         -5.91666667  3.375      -0.45833333]
# 4.000000000000021
# [ 0.         -0.69079365 -0.2831746   0.1445805 ]
# 3.0569614512471652
# [ 0.         -0.15897295 -0.13423067  0.0815601 ]
# 2.4944418431229725

# %% [markdown]
# ### 5. Regularizirana polinomijalna regresija

# %% [markdown]
# #### (a)
#
# Vratimo se na slučaj $N=50$ slučajno generiranih primjera iz zadatka 2. Trenirajte modele polinomijalne regresije $\mathcal{H}_{\lambda,d}$ za $\lambda\in\{0,100\}$ i $d\in\{2,10\}$ (ukupno četiri modela). Skicirajte pripadne funkcije $h(\mathbf{x})$ i primjere (na jednom grafikonu; preporučujemo koristiti `plot` unutar `for` petlje).
#
# **Q:** Jesu li rezultati očekivani? Obrazložite.

# %%
X = make_instances(-5, 5, 50)
y = list(make_labels(X, f, 200))#ovaj map se ponasa generator, ne vrati sve odjednom nego pozivom vraca iduci elemnt, pa ga se ocvako natira da vrati sve
y = np.array(y)

lambda_list = [0,100]
d_list = [2,10]

plt.scatter(X, y, label="Data")

for d in d_list:
    poly = PolynomialFeatures(d)
    psi = poly.fit_transform(X)
    for l in lambda_list:
        clf = Ridge(alpha = l)
        clf.fit(psi, y)
        
        h = clf.predict(psi)
        plt.plot(X, h, label="d = " + str(d) + ", lambda = " + str(l))

plt.legend()
plt.show()

# %% [markdown]
# #### (b)
#
# Kao u zadataku 3b, razdvojite primjere na skup za učenje i skup za ispitivanje u omjeru 1:1. Prikažite krivulje logaritama pogreške učenja i ispitne pogreške u ovisnosti za model $\mathcal{H}_{d=20,\lambda}$, podešavajući faktor regularizacije $\lambda$ u rasponu $\lambda\in\{0,1,\dots,50\}$.
#
# **Q:** Kojoj strani na grafikonu odgovara područje prenaučenosti, a kojoj podnaučenosti? Zašto?
#
# **Q:** Koju biste vrijednosti za $\lambda$ izabrali na temelju ovih grafikona i zašto?

# %%
# Out:
# [0, 51]

# %%
poly = PolynomialFeatures(20)
psi = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(psi, y, test_size=0.5)

Train_err = []
Test_err = []

for l in range(0, 51):
    
    clf = Ridge(alpha=l)
    clf.fit(X_train, y_train)
        
    h = clf.predict(X_train)
    Train_err.append(np.log(sklearn.metrics.mean_squared_error(y_train, h)))
        
    h = clf.predict(X_test)
    Test_err.append(np.log(sklearn.metrics.mean_squared_error(y_test, h)))

plt.plot(range(51), Train_err, label="Log train error")
plt.plot(range(51), Test_err, label="Log test error")
plt.legend()
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 2.0384854012380453e-28 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 4.209726793305756e-28 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 6.229555073530847e-28 / 1.1102230246251565e-16
#   RuntimeWarning)
# C:\Program Files\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# ...

# %% [markdown]
# ### 6. L1-regularizacija i L2-regularizacija

# %% [markdown]
# Svrha regularizacije jest potiskivanje težina modela $\mathbf{w}$ prema nuli, kako bi model bio što jednostavniji. Složenost modela može se okarakterizirati normom pripadnog vektora težina $\mathbf{w}$, i to tipično L2-normom ili L1-normom. Za jednom trenirani model možemo izračunati i broj ne-nul značajki, ili L0-normu, pomoću sljedeće funkcije:

# %%
def nonzeroes(coef, tol=1e-6): 
    return len(coef) - len(coef[np.isclose(0, coef, atol=tol)])

# %% [markdown]
# #### (a)
#
# Za ovaj zadatak upotrijebite skup za učenje i skup za testiranje iz zadatka 3b. Trenirajte modele **L2-regularizirane** polinomijalne regresije stupnja $d=20$, mijenjajući hiperparametar $\lambda$ u rasponu $\{1,2,\dots,100\}$. Za svaki od treniranih modela izračunajte L{0,1,2}-norme vektora težina $\mathbf{w}$ te ih prikažite kao funkciju od $\lambda$.
#
# **Q:** Objasnite oblik obiju krivulja. Hoće li krivulja za $\|\mathbf{w}\|_2$ doseći nulu? Zašto? Je li to problem? Zašto?
#
# **Q:** Za $\lambda=100$, koliki je postotak težina modela jednak nuli, odnosno koliko je model rijedak?

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
import warnings

warnings.filterwarnings("ignore")

X = make_instances(-5, 5, 50)
y = list(make_labels(X, f, 200))
y = np.array(y)
poly = PolynomialFeatures(20)
psi = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(psi, y, test_size=0.5)

l0 = []
l1 = []
l2 = []
for l in range(1, 101):
        clf = Ridge(alpha = l)
        clf.fit(X_train, y_train)
        #coefs = []
        #coefs.append(clf.intercept_)
        #coefs.append(clf.coef_)
        #coefs = coefs.flatten()
        #coefs = np.array(coefs)
        #print(coefs)
        
        coefs = clf.coef_
        coefs[0] = clf.intercept_ #nisan 100% sig jel ovo triba, al inace prvi koef bude uvik 0
        coefs = coefs.flatten()
        
        l0norm = nonzeroes(coefs)
        l1norm = np.sum(np.abs(coefs))
        l2norm = np.sqrt(np.matmul(coefs.transpose(), coefs))
        l0.append(l0norm)
        l1.append(l1norm)
        l2.append(l2norm)

plt.plot(range(1, 101), l0, label="L0")
plt.plot(range(1, 101), l1, label="L1")
plt.plot(range(1, 101), l2, label="L2")
plt.legend()
plt.show()

# %% [markdown]
# #### (b)

# %% [markdown]
# Glavna prednost L1-regularizirane regresije (ili *LASSO regression*) nad L2-regulariziranom regresijom jest u tome što L1-regularizirana regresija rezultira **rijetkim modelima** (engl. *sparse models*), odnosno modelima kod kojih su mnoge težine pritegnute na nulu. Pokažite da je to doista tako, ponovivši gornji eksperiment s **L1-regulariziranom** regresijom, implementiranom u klasi  [`Lasso`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) u modulu [`sklearn.linear_model`](http://scikit-learn.org/stable/modules/classes.html#module-sklearn.linear_model).

# %%
X = make_instances(-5, 5, 50)
y = list(make_labels(X, f, 200))
y = np.array(y)
poly = PolynomialFeatures(20)
psi = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(psi, y, test_size=0.5)

l0 = []
l1 = []
l2 = []
for l in range(1, 101):
        clf = Lasso(alpha = l)
        clf.fit(X_train, y_train)
        #coefs = []
        #coefs.append(clf.intercept_)
        #coefs.extend(clf.coef_)
        #coefs = coefs.flatten()
        #coefs = np.array(coefs)
        #print(coefs)
        
        coefs = clf.coef_
        coefs[0] = clf.intercept_ #nisan 100% sig jel ovo triba, al inace prvi koef bude uvik 0
        coefs = coefs.flatten()
        
        l0norm = nonzeroes(coefs)
        l1norm = np.sum(np.abs(coefs))
        l2norm = np.sqrt(np.matmul(coefs.transpose(), coefs))
        l0.append(l0norm)
        l1.append(l1norm)
        l2.append(l2norm)

plt.plot(range(1, 101), l0, label="L0")
plt.plot(range(1, 101), l1, label="L1")
plt.plot(range(1, 101), l2, label="L2")
plt.legend()
plt.show()

# %% [markdown]
# ### 7. Značajke različitih skala

# %% [markdown]
# Često se u praksi možemo susreti sa podatcima u kojima sve značajke nisu jednakih magnituda. Primjer jednog takvog skupa je regresijski skup podataka `grades` u kojem se predviđa prosjek ocjena studenta na studiju (1--5) na temelju dvije značajke: bodova na prijamnom ispitu (1--3000) i prosjeka ocjena u srednjoj školi. Prosjek ocjena na studiju izračunat je kao težinska suma ove dvije značajke uz dodani šum.
#
# Koristite sljedeći kôd kako biste generirali ovaj skup podataka.

# %%
n_data_points = 500
np.random.seed(69)

# Generiraj podatke o bodovima na prijamnom ispitu koristeći normalnu razdiobu i ograniči ih na interval [1, 3000].
exam_score = np.random.normal(loc=1500.0, scale = 500.0, size = n_data_points) 
exam_score = np.round(exam_score)
exam_score[exam_score > 3000] = 3000
exam_score[exam_score < 0] = 0

# Generiraj podatke o ocjenama iz srednje škole koristeći normalnu razdiobu i ograniči ih na interval [1, 5].
grade_in_highschool = np.random.normal(loc=3, scale = 2.0, size = n_data_points)
grade_in_highschool[grade_in_highschool > 5] = 5
grade_in_highschool[grade_in_highschool < 1] = 1

# Matrica dizajna.
grades_X = np.array([exam_score,grade_in_highschool]).T

# Završno, generiraj izlazne vrijednosti.
rand_noise = np.random.normal(loc=0.0, scale = 0.5, size = n_data_points)
exam_influence = 0.9
grades_y = ((exam_score / 3000.0) * (exam_influence) + (grade_in_highschool / 5.0) \
            * (1.0 - exam_influence)) * 5.0 + rand_noise
grades_y[grades_y < 1] = 1
grades_y[grades_y > 5] = 5

# %% [markdown]
# **a)**

# %% [markdown]
# Iscrtajte ovisnost ciljne vrijednosti (y-os) o prvoj i o drugoj značajki (x-os). Iscrtajte dva odvojena grafa.

# %%
plt.scatter(grades_X[:,0], grades_y)
plt.title("Ovisnost prosjeka ocjena na studiju o prijemnom ispitu")
plt.show()
plt.scatter(grades_X[:,1], grades_y)
plt.title("Ovisnost prosjeka ocjena na studiju o prosjeku u srednjoj skoli")
plt.show()

# %% [markdown]
# **b)**

# %% [markdown]
# Naučite model L2-regularizirane regresije ($\lambda = 0.01$), na podacima `grades_X` i `grades_y`:

# %%
clf = Ridge(alpha=0.01)
clf.fit(grades_X, grades_y)
print(clf.coef_)
# Out:
# [0.00141497 0.09477276]

# %% [markdown]
# Sada ponovite gornji eksperiment, ali prvo skalirajte podatke `grades_X` i `grades_y` i spremite ih u varijable `grades_X_fixed` i `grades_y_fixed`. Za tu svrhu, koristite [`StandardScaler`](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html).

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(grades_X)
grades_X_fixed = scaler.transform(grades_X)
scaler.fit(grades_y)
grades_y_fixed = scaler.transform(grades_y)
clf = Ridge(alpha=0.01)
clf.fit(grades_X_fixed, grades_y_fixed)
print(clf.coef_)
# Out:
# [0.81630375 0.15167761]

# %% [markdown]
# **Q:** Gledajući grafikone iz podzadatka (a), koja značajka bi trebala imati veću magnitudu, odnosno važnost pri predikciji prosjeka na studiju? Odgovaraju li težine Vašoj intuiciji? Objasnite.

# %% [markdown]
# ### 8. Multikolinearnost i kondicija matrice

# %% [markdown]
# **a)**

# %% [markdown]
# Izradite skup podataka `grades_X_fixed_colinear` tako što ćete u skupu `grades_X_fixed` iz
# zadatka 7b duplicirati zadnji stupac (ocjenu iz srednje škole). Time smo efektivno uveli savršenu multikolinearnost.

# %%
grades_X_fixed_colinear = np.concatenate((grades_X_fixed,grades_X_fixed[:,1:2]),axis=-1)

# %% [markdown]
# Ponovno, naučite na ovom skupu L2-regularizirani model regresije ($\lambda = 0.01$).

# %%
clf = Ridge(alpha=0.01)
clf.fit(grades_X_fixed_colinear, grades_y_fixed)
print(clf.coef_)
# Out:
# [0.81630364 0.07583957 0.07583957]

# %% [markdown]
# **Q:** Usporedite iznose težina s onima koje ste dobili u zadatku *7b*. Što se dogodilo?

# %% [markdown]
# **b)**

# %% [markdown]
# Slučajno uzorkujte 50% elemenata iz skupa `grades_X_fixed_colinear` i naučite dva modela L2-regularizirane regresije, jedan s $\lambda=0.01$, a jedan s $\lambda=1000$. Ponovite ovaj pokus 10 puta (svaki put s drugim podskupom od 50% elemenata).  Za svaki model, ispišite dobiveni vektor težina u svih 10 ponavljanja te ispišite standardnu devijaciju vrijednosti svake od težina (ukupno šest standardnih devijacija, svaka dobivena nad 10 vrijednosti).

# %%
vectorW1 = []
vectorW2 = []
vectorSD = []
for t in range(10):
    list_index = np.random.choice(np.arange(len(grades_X_fixed_colinear)), int(len(grades_X_fixed_colinear)/2), replace=False)
    newX = grades_X_fixed_colinear[list_index]
    newY = grades_y[list_index]
    clf = Ridge(alpha=0.01)
    clf.fit(newX, newY)
    vectorW1.append(clf.coef_)
    print("Pokus br. ", t, ": Tezine za lambda = 0.01 iznose: ", clf.coef_)
    
    clf = Ridge(alpha = 1000)
    clf.fit(newX, newY)
    vectorW2.append(clf.coef_)
    print("Pokus br. ", t, ": Tezine za lambda = 1000 iznose: ", clf.coef_)
    
print("Mean za lambda = 0.01: ", np.mean(vectorW1, axis=0))
print("Standardna deviacija za lambda = 0.01: ", np.std(vectorW1, axis=0))

print("Mean za lambda = 1000: ", np.mean(vectorW2, axis=0))
print("Standardna deviacija za lambda = 1000: ", np.std(vectorW2, axis=0))
# Out:
# Pokus br.  0 : Tezine za lambda = 0.01 iznose:  [0.74288017 0.06719608 0.06719608]
# Pokus br.  0 : Tezine za lambda = 1000 iznose:  [0.15107604 0.03616774 0.03616774]
# Pokus br.  1 : Tezine za lambda = 0.01 iznose:  [0.72355512 0.06948433 0.06948433]
# Pokus br.  1 : Tezine za lambda = 1000 iznose:  [0.14705785 0.02947751 0.02947751]
# Pokus br.  2 : Tezine za lambda = 0.01 iznose:  [0.75933563 0.06302567 0.06302567]
# Pokus br.  2 : Tezine za lambda = 1000 iznose:  [0.15491875 0.03612425 0.03612425]
# Pokus br.  3 : Tezine za lambda = 0.01 iznose:  [0.74704508 0.09864121 0.09864121]
# Pokus br.  3 : Tezine za lambda = 1000 iznose:  [0.13592283 0.03129226 0.03129226]
# Pokus br.  4 : Tezine za lambda = 0.01 iznose:  [0.74971765 0.07942889 0.07942889]
# Pokus br.  4 : Tezine za lambda = 1000 iznose:  [0.15645841 0.03912421 0.03912421]
# Pokus br.  5 : Tezine za lambda = 0.01 iznose:  [0.7428867  0.07759254 0.07759254]
# ...

# %% [markdown]
# **Q:** Kako regularizacija utječe na stabilnost težina?
# **Q:** Jesu li koeficijenti jednakih magnituda kao u prethodnom pokusu? Objasnite zašto.

# %% [markdown]
# **c)**

# %% [markdown]
# Koristeći [`numpy.linalg.cond`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.linalg.cond.html) izračunajte kondicijski broj matrice $\mathbf{\Phi}^\intercal\mathbf{\Phi}+\lambda\mathbf{I}$, gdje je $\mathbf{\Phi}$ matrica dizajna (`grades_fixed_X_colinear`). Ponovite i za $\lambda=0.01$ i za $\lambda=10$.

# %%
temp = np.matmul(grades_X_fixed_colinear.transpose(),grades_X_fixed_colinear)
mat = temp + 0.01*np.identity(np.shape(temp)[0])
print("Kondicijski broj za l=0.01: ",np.linalg.cond(mat))
mat=temp + 10*np.identity(np.shape(temp)[0])
print("Kondicijski broj za l=10: ",np.linalg.cond(mat))
# Out:
# Kondicijski broj za l=0.01:  100542.86653460482
# Kondicijski broj za l=10:  101.54186653499362

# %% [markdown]
# **Q:** Kako regularizacija utječe na kondicijski broj matrice $\mathbf{\Phi}^\intercal\mathbf{\Phi}+\lambda\mathbf{I}$?
